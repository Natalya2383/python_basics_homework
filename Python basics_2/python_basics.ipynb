# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

print('Задание: СРАВНИТЬ ДЛИНЫ ДВУХ ФРАЗ\n')
print('Длина фразы "long_phrase" равна:', len(long_phrase), 'символов')
print('Длина фразы "short_phrase" равна:' , len(short_phrase), 'символов\n')
print('Результат сравнения двух строк:', len(long_phrase) > len(short_phrase))
print()
print ("Конец программы")
# Out:
# Задание: СРАВНИТЬ ДЛИНЫ ДВУХ ФРАЗ
#
# Длина фразы "long_phrase" равна: 62 символов
# Длина фразы "short_phrase" равна: 61 символов
#
# Результат сравнения двух строк: True
#
# Конец программы

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах (*в мегабайте 2^20 байт*). Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*".

# %%
print('Задание: ПЕРЕВЕСТИ РАЗМЕР ФАЙЛА ИЗ БАЙТОВ В МЕГАБАЙТЫ\n')

print('Введите размер файла в байтах:')
file_byte = int(input())

file_Mb = file_byte / (2**20)
print("Объем файла равен", round(file_Mb,2), "Mb\n")
print ("Конец программы")
# Out:
# Задание: ПЕРЕВЕСТИ РАЗМЕР ФАЙЛА ИЗ БАЙТОВ В МЕГАБАЙТЫ
#
# Введите размер файла в байтах:
# 5000000
# Объем файла равен 4.77 Mb
#
# Конец программы

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
# ВВОД ДАННЫХ С КОНСОЛИ И ИХ ПРОВЕРКА
print("ДАННАЯ ПРОГРАММА ОПРЕДЕЛЯЕТ ВАШ ЗНАК ЗОДИАКА ПО ДАТЕ РОЖДЕНИЯ\n")
print("Введите месяц рождения (от 1 до 12): ")
month = int(input())
if (month > 12):
    print("В году только 12 месяцев))")

if (month == 1 or month == 3 or month == 5 or month == 7 or month == 8 or month == 10 or month == 12):
    print("Введите день рождения (от 1 до 31):")
    date = int(input())
    if (date > 31):
        print("День рождения в этом месяце не может быть больше 31.")
        
if (month == 4 or month == 6 or month == 9 or month == 11):
    print("Введите день рождения (от 1 до 30):")
    date = int(input())
    if (date > 30):
        print("День рождения в этом месяце не может быть больше 30.")
    
    
if (month == 2):
    print("Введите день рождения (от 1 до 29):")
    date = int(input())
    if (date > 30):
        print("День рождения в этом месяце не может быть больше 29.")    

# ПРОВЕРКА НА ЗНАК ЗОДИАКА
if (month == 3 and 21 <= date <= 31) or (month == 4 and 1 <= date <= 19):
    print("ОВЕН")
if (month == 4 and 20 <= date <= 30) or (month == 5 and 1 <= date <= 20):
    print("ТЕЛЕЦ")
if (month == 5 and 21 <= date <= 31) or (month == 6 and 1 <= date <= 20):
    print("БЛИЗНЕЦЫ")
if (month == 6 and 21 <= date <= 30) or (month == 7 and 1 <= date <= 22):
    print("РАК")
if (month == 7 and 23 <= date <= 31) or (month == 8 and 1 <= date <= 22):
    print("ЛЕВ")
if (month == 8 and 23 <= date <= 31) or (month == 9 and 1 <= date <= 22):
    print("ДЕВА")
if (month == 9 and 23 <= date <= 30) or (month == 10 and 1 <= date <= 22):
    print("ВЕСЫ")
if (month == 10 and 23 <= date <= 31) or (month == 11 and 1 <= date <= 21):
    print("СКОРПИОН")
if (month == 11 and 22 <= date <= 30) or (month == 12 and 1 <= date <= 21):
    print("СТРЕЛЕЦ")
if (month == 12 and 22 <= date <= 31) or (month == 1 and 1 <= date <= 19):
    print("КОЗЕРОГ")
if (month == 1 and 20 <= date <= 31) or (month == 2 and 1 <= date <= 18):
    print("ВОДОЛЕЙ")
if (month == 2 and 19 <= date <= 29) or (month == 3 and 1 <= date <= 20):
    print("РЫБЫ") 

print("\nКонец программы")
# Out:
# ДАННАЯ ПРОГРАММА ОПРЕДЕЛЯЕТ ВАШ ЗНАК ЗОДИАКА ПО ДАТЕ РОЖДЕНИЯ
#
# Введите месяц рождения (от 1 до 12):
# 6
# Введите день рождения (от 1 до 30):
# 25
# РАК
#
# Конец программы

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
# Введите сколько процентов уходит на ипотеку: 30
# Введите сколько процентов уходит на жизнь: 50
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
# ВВОД ДАННЫХ С КОНСОЛИ И ИХ ПРОВЕРКА
print("ДАННАЯ ПРОГРАММА ПРЕДНАЗНАЧЕНА ДЛЯ ФИНАНСОВОГО ПЛАНИРОВАНИЯ\n")

print("Введите размер заработной платы в рублях в месяц:")
salary = int(input())
print("Введите процент от заработной платы, который уходит на ипотеку в месяц:")
mortgage_part = int(input())
print("Введите процент от заработной платы, который уходит на жизнь в месяц:")
life_part = int(input())
print("Введите количество премий в год:")
bonus_count = int(input())

# РАСЧЕТЫ
bonus = salary * bonus_count #годовой бонус, руб.
vacation = bonus * 0.5  #на отпуск за год, руб.
savings_bonus = bonus * 0.5 #сбережения от бонусов за год, руб.
mortgage = format(salary * 12 * mortgage_part /100, '.0f') #плата по ипотеке за год, руб.
savings_salary = salary * 12 * (1-(mortgage_part + life_part)/100)
saving_total = format(savings_bonus + savings_salary, '.0f')

print("\nВывод:\nНа ипотеку было потрачено за год:", mortgage, "рублей.\nБыло накоплено за год:", 
      saving_total, "рублей.")
print("\nКонец программы")
# Out:
# ДАННАЯ ПРОГРАММА ПРЕДНАЗНАЧЕНА ДЛЯ ФИНАНСОВОГО ПЛАНИРОВАНИЯ
#
# Введите размер заработной платы в рублях в месяц:
# 100000
# Введите процент от заработной платы, который уходит на ипотеку в месяц:
# 30
# Введите процент от заработной платы, который уходит на жизнь в месяц:
# 50
# Введите количество премий в год:
# 2
#
# Вывод:
# На ипотеку было потрачено за год: 360000 рублей.
# Было накоплено за год: 340000 рублей.
#
# Конец программы

# %%
# ВВОД ДАННЫХ С КОНСОЛИ И ИХ ПРОВЕРКА
print("ДАННАЯ ПРОГРАММА ПРЕДНАЗНАЧЕНА ДЛЯ ХХХХХХХХХХХХХ\n")

print("Введите слово из латинских букв")
string = input()
if (len(string) % 2):
    print("четное")
else: 
    print("нечетное")
    
print("\nКонец программы")
# Out:
# ДАННАЯ ПРОГРАММА ПРЕДНАЗНАЧЕНА ДЛЯ ХХХХХХХХХХХХХ
#
# Введите слово из латинских букв
# stringq
# четное
#
# Конец программы
